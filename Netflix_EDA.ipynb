# %% [markdown]
# This dataset collected from Netflix of different TV shows and Movies from the year 2008 to 2021.
#
# **show_id**: Gives the information about show id.
#
# **type**: Gives information about 2 different unique values one is TV Show and another is Movie.
#
# **title**: Gives information about the title of Movie or TV Show.
#
# **director**: Gives information about the director who directed the Movie or TV Show.
#
# **cast**: Gives information about the cast who plays role in Movie or TV Show.
#
# **country**: Gives information about the Name of country.
#
# **date_added**: Gives information about the tv shows or movie released.
#
# **release_year**: Gives information about the year when Movie or TV Show was released.
#
# **rating**: Gives information about the Movie or TV Show are in which category (eg like the movies are only for students, or adults, etc).
#
# **duration**: Gives information about the duration of Movie or TV Show.
#
# **listed_in**: Gives information about the genre of Movie or TV Show.
#
# **description**: Gives information about the description of Movie or TV Show.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
sns.set()
import gdown
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import seaborn as sns
#       4 from matplotlib import pyplot as plt
#       5 sns.set()
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
#url = "https://drive.google.com/file/d/1T7WBRIdBp1NFlUtwCNweP3ad8Yjd6An5/view?usp=drive_link"
#output = "netflix.csv"
#gdown.download(url, output, quiet=False)

# %%
netflix = pd.read_csv("/content/netflix_titles_2021.csv")

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.tail()
# Out:
#      show_id     type        title         director  \
# 8802   s8803    Movie       Zodiac    David Fincher
# 8803   s8804  TV Show  Zombie Dumb              NaN
# 8804   s8805    Movie   Zombieland  Ruben Fleischer
# 8805   s8806    Movie         Zoom     Peter Hewitt
# 8806   s8807    Movie       Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
# 8803                                                NaN            NaN
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#              date_added  release_year rating   duration  \
# 8802  November 20, 2019          2007      R    158 min
# 8803       July 1, 2019          2018  TV-Y7  2 Seasons
# ...

# %%
netflix.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
netflix["date_added"]=pd.to_datetime(netflix['date_added'])
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
netflix['year_added'] = netflix["date_added"].dt.year
netflix['month_added'] = netflix["date_added"].dt.month
netflix.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description  year_added  month_added
# 0  As her father nears the end of his life, filmm...      2021.0          9.0
# 1  After crossing paths at a party, a Cape Town t...      2021.0          9.0

# %%
netflix.describe()
# Out:
#        release_year   year_added  month_added
# count   8807.000000  8797.000000  8797.000000
# mean    2014.180198  2018.871888     6.654996
# std        8.819312     1.574243     3.436554
# min     1925.000000  2008.000000     1.000000
# 25%     2013.000000  2018.000000     4.000000
# 50%     2017.000000  2019.000000     7.000000
# 75%     2019.000000  2020.000000    10.000000
# max     2021.000000  2021.000000    12.000000

# %%
netflix.nunique()
# Out:
# show_id         8807
# type               2
# title           8807
# director        4528
# cast            7692
# country          748
# date_added      1714
# release_year      74
# rating            17
# duration         220
# listed_in        514
# description     8775
# year_added        14
# month_added       12
# dtype: int64

# %%
null_val = netflix.isnull().sum()
null_val
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# year_added        10
# month_added       10
# dtype: int64

# %%
sns.heatmap(netflix.isnull())
# Out:
# <Axes: >

# %%
netflix_copy = netflix.copy()
netflix_copy.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
netflix_copy =netflix_copy.dropna(how='any',subset=['director','cast'])
netflix_copy.head()
# Out:
#   show_id     type                             title  \
# 2      s3  TV Show                         Ganglands
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
#
#                         director  \
# 2                Julien Leclercq
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
#
#                                                 cast  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...
# 6  Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 8  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
#
#                                              country date_added  release_year  \
# ...

# %%
netflix_copy.fillna({'country':'missing','rating':'missing','duration':'missing'},inplace=True)
netflix_copy.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# year_added      0
# month_added     0
# dtype: int64

# %%
netflix_copy.shape
# Out:
# (5700, 14)

# %%
netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added
# 2  To protect his family from a powerful drug lor...      2021.0          9.0
# 5  The arrival of a charismatic young priest brin...      2021.0          9.0

# %%
netflix_copy.groupby('type')['title'].count().sort_values(ascending = False)
# Out:
# type
# Movie      5522
# TV Show     178
# Name: title, dtype: int64

# %%
netflix_copy.groupby('type')['title'].count().sort_values(ascending = False).plot(kind='bar')
plt.show()

# %%
labels = ['TV Show', 'Movie']
sizes = [len(netflix_copy[netflix_copy['type'] == 'TV Show']), len(netflix_copy[netflix_copy['type'] == 'Movie'])]
colors = ['gold', 'yellowgreen']
explode = [0.1, 0]

plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title('TV Show vs Movies')
plt.show()

# %%
netflix_copy.dtypes
# Out:
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added      datetime64[ns]
# release_year             int64
# rating                  object
# duration                object
# listed_in               object
# description             object
# year_added             float64
# month_added            float64
# dtype: object

# %%
netflix_copy.corr()
# Out:
# <ipython-input-106-bd7c04c03a76>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   netflix_copy.corr()
#               release_year  year_added  month_added
# release_year      1.000000    0.032265    -0.062903
# year_added        0.032265    1.000000    -0.170078
# month_added      -0.062903   -0.170078     1.000000

# %%
plt.subplots(figsize=(5,5))
sns.heatmap(netflix_copy.corr(),annot=True)
plt.show()
# Out:
# <ipython-input-107-4f9d96a0b42c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(netflix_copy.corr(),annot=True)

# %%
netflix_copy['rating'].value_counts().sort_values().plot(kind='barh')
plt.title('Count of Ratings')
plt.show()

# %%
# prompt: alternative of : netflix.groupby("type")["rating"].agg(pd.Series.mode)

netflix.groupby("type")["rating"].apply(pd.Series.mode)
# Out:
# type
# Movie    0    TV-MA
# TV Show  0    TV-MA
# Name: rating, dtype: object

# %%
netflix_copy['month_final'] = netflix_copy['month_added'].replace({1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'June', 7:'July', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec'})
netflix_copy.head(2)
# Out:
#   show_id     type          title         director  \
# 2      s3  TV Show      Ganglands  Julien Leclercq
# 5      s6  TV Show  Midnight Mass    Mike Flanagan
#
#                                                 cast  country date_added  \
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  missing 2021-09-24
# 5  Kate Siegel, Zach Gilford, Hamish Linklater, H...  missing 2021-09-24
#
#    release_year rating  duration  \
# 2          2021  TV-MA  1 Season
# 5          2021  TV-MA  1 Season
#
#                                            listed_in  \
# 2  Crime TV Shows, International TV Shows, TV Act...
# 5                 TV Dramas, TV Horror, TV Mysteries
#
#                                          description  year_added  month_added  \
# 2  To protect his family from a powerful drug lor...      2021.0          9.0
# 5  The arrival of a charismatic young priest brin...      2021.0          9.0
#
#   month_final
# 2         Sep
# 5         Sep

# %%
from matplotlib import pyplot as plt
netflix_copy['release_year'].plot(kind='hist', bins=20, title='release_year')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
netflix_copy.month_final.value_counts().rename_axis('month_final').reset_index(name='Value_count')
# Out:
#    month_final  Value_count
# 0         July          535
# 1          Dec          511
# 2          Oct          507
# 3          Jan          503
# 4          Apr          501
# 5          Mar          497
# 6          Aug          492
# 7          Sep          475
# 8          Nov          468
# 9         June          457
# 10         May          405
# 11         Feb          349

# %%
sns.countplot(x="month_final", data=netflix_copy, order=netflix_copy['month_final'].value_counts().index)
plt.title("Movies and TV Shows released per month")
plt.xlabel("Month")
plt.ylabel("Count")
plt.show()

# %%
new_genre = netflix_copy['listed_in'].str.split(",",2)
new_genre
# Out:
# <ipython-input-136-a8c86644b719>:1: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   new_genre = netflix_copy['listed_in'].str.split(",",2)
# 2       [Crime TV Shows,  International TV Shows,  TV ...
# 5                  [TV Dramas,  TV Horror,  TV Mysteries]
# 6                              [Children & Family Movies]
# 7       [Dramas,  Independent Movies,  International M...
# 8                         [British TV Shows,  Reality TV]
#                               ...
# 8801          [Dramas,  International Movies,  Thrillers]
# 8802                   [Cult Movies,  Dramas,  Thrillers]
# 8804                           [Comedies,  Horror Movies]
# 8805                [Children & Family Movies,  Comedies]
# 8806    [Dramas,  International Movies,  Music & Music...
# Name: listed_in, Length: 5700, dtype: object

# %%
netflix_copy['Genre 1'] = new_genre.str.get(0)
netflix_copy['Genre 2'] = new_genre.str.get(1)
netflix_copy['Genre 3'] = new_genre.str.get(2)
netflix_copy.head(2)

# %%
netflix_copy.groupby(['Genre 1']).agg(release_year_count=('release_year', 'count')).sort_values(by='release_year_count', ascending=False)
# Out:
#                               release_year_count
# Genre 1
# Dramas                                      1466
# Comedies                                    1072
# Action & Adventure                           676
# Children & Family Movies                     506
# Documentaries                                386
# Stand-Up Comedy                              293
# Horror Movies                                265
# International Movies                         120
# International TV Shows                        59
# Thrillers                                     54
# Crime TV Shows                                37
# Movies                                        29
# Independent Movies                            20
# British TV Shows                              20
# Anime Features                                19
# Music & Musicals                              18
# Sci-Fi & Fantasy                              13
# Kids' TV                                      11
# ...

# %%
netflix_copy.groupby(['Genre 2']).agg(release_year_count=('release_year', 'count')).sort_values(by='release_year_count', ascending=False)
# Out:
#                                release_year_count
# Genre 2
#  International Movies                        1545
#  Dramas                                       744
#  Independent Movies                           572
#  Comedies                                     440
#  Thrillers                                    232
#  Romantic Movies                              170
#  Music & Musicals                             119
#  Sci-Fi & Fantasy                             109
#  Horror Movies                                 71
#  Sports Movies                                 68
#  Anime Features                                49
#  Faith & Spirituality                          49
#  Cult Movies                                   44
#  International TV Shows                        41
#  Children & Family Movies                      31
#  Classic Movies                                30
#  LGBTQ Movies                                  30
#  TV Dramas                                     23
# ...

# %%
netflix_copy.groupby(['Genre 3']).agg(release_year_count=('release_year', 'count')).sort_values(by='release_year_count', ascending=False)
# Out:
#                                release_year_count
# Genre 3
#  International Movies                         881
#  Romantic Movies                              431
#  Thrillers                                    278
#  Music & Musicals                             191
#  Independent Movies                           159
#  Sci-Fi & Fantasy                             115
#  Sports Movies                                 95
#  Dramas                                        68
#  LGBTQ Movies                                  52
#  TV Dramas                                     36
#  TV Comedies                                   16
#  Cult Movies                                   14
#  Comedies                                      12
#  Faith & Spirituality                          11
#  Spanish-Language TV Shows                     10
#  TV Mysteries                                  10
#  TV Action & Adventure                          7
#  International TV Shows                         7
# ...

# %%
genre_types = ['Genre 1','Genre 2','Genre 3']
Value_count = netflix_copy.groupby(['Genre 1'])['release_year'].count().sort_values(ascending = False).head(3).values
plt.pie(Value_count, labels = genre_types, autopct="%2.2f%%")
plt.legend(title='Most watched genre on Netflix')
plt.show()

# %%
df = netflix_copy.groupby(['release_year']).agg(release_year_count=('release_year', 'count')).sort_values(by='release_year_count', ascending=False)
df.head(10)
# Out:
#               release_year_count
# release_year
# 2018                         691
# 2017                         684
# 2016                         584
# 2019                         570
# 2020                         499
# 2015                         367
# 2021                         256
# 2014                         252
# 2013                         209
# 2012                         169

# %%
sns.histplot(data=df, x='release_year', bins='auto', hue='release_year_count')
# Out:
# <Axes: xlabel='release_year', ylabel='Count'>
